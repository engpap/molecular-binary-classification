# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers.legacy import Adam
import matplotlib.pyplot as plt

DATASET_PATH = './dataset/20000/'
NUM_EPOCHS = 30
SEED = 42
NUM_SAMPLES_20000 = True
DEBUG = True

def debug_print(message):
    if DEBUG:
        print(message)

synthetic_data_files = os.listdir(DATASET_PATH)
data_files = [file for file in synthetic_data_files if file.startswith('A') and '020000s' in file]
print(f"Len of datafiles: {len(data_files)}")
# Out:
# Len of datafiles: 288

# %% [markdown]
# ## Prepare dataset

# %%
functional_labels = ['ELF', 'ELL', 'ELT', 'FLF', 'FLL', 'FLT']
data_matrices = {}
labels = {}

for file in data_files:
    file_path = os.path.join(DATASET_PATH, file)
    molecule_name = file.split('s')[1]
    data_matrix = pd.read_csv(file_path, header=None).values
    data_matrices[molecule_name] = data_matrix.flatten()  # flattening the data matrix
    labels[molecule_name] = 1 if any(label in molecule_name for label in functional_labels) else 0

all_data = np.array(list(data_matrices.values()))
all_labels = np.array(list(labels.values()))

X_train, X_test, y_train, y_test = train_test_split(
    all_data, all_labels, test_size=0.3, stratify=all_labels, random_state=SEED
)

scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

print("Train: ", X_train.shape)
print("Test: ", X_test.shape)
# Out:
# Train:  (201, 1160000)
# Test:  (87, 1160000)

# %% [markdown]
# # Logistic Regression Model

# %%
# Logistic Regression Model
model = Sequential()
# Dense implements the operation: output = activation(dot(input, kernel) + bias)
# Ref: https://keras.io/api/layers/core_layers/dense/

model.add(Dense(1, # Output
                activation='sigmoid', # Binary classification
                input_shape=(X_train.shape[1],)
                ))

model.compile(optimizer=Adam(learning_rate=0.000001),
              loss='binary_crossentropy',
              metrics=['accuracy']
              )

model.summary()

history = model.fit(X_train, y_train, epochs=NUM_EPOCHS, batch_size=64, validation_data=(X_test, y_test), verbose=1)

test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f"Test accuracy: {test_accuracy:.3f}")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 1160001
#
# =================================================================
# Total params: 1,160,001
# Trainable params: 1,160,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 4/4 [==============================] - 11s 3s/step - loss: 0.8890 - accuracy: 0.4975 - val_loss: 0.7472 - val_accuracy: 0.6092
# Epoch 2/30
# 4/4 [==============================] - 2s 265ms/step - loss: 0.6736 - accuracy: 0.6020 - val_loss: 0.6488 - val_accuracy: 0.6437
# Epoch 3/30
# 4/4 [==============================] - 0s 79ms/step - loss: 0.5542 - accuracy: 0.6816 - val_loss: 0.5693 - val_accuracy: 0.6667
# Epoch 4/30
# 4/4 [==============================] - 0s 94ms/step - loss: 0.4631 - accuracy: 0.7562 - val_loss: 0.5072 - val_accuracy: 0.7126
# Epoch 5/30
# 4/4 [==============================] - 0s 54ms/step - loss: 0.3941 - accuracy: 0.8060 - val_loss: 0.4561 - val_accuracy: 0.7471
# Epoch 6/30
# 4/4 [==============================] - 1s 211ms/step - loss: 0.3411 - accuracy: 0.8507 - val_loss: 0.4150 - val_accuracy: 0.8161
# Epoch 7/30
# 4/4 [==============================] - 0s 104ms/step - loss: 0.3004 - accuracy: 0.8955 - val_loss: 0.3796 - val_accuracy: 0.8276
# Epoch 8/30
# 4/4 [==============================] - 1s 224ms/step - loss: 0.2645 - accuracy: 0.9104 - val_loss: 0.3446 - val_accuracy: 0.8621
# Epoch 9/30
# 4/4 [==============================] - 1s 213ms/step - loss: 0.2362 - accuracy: 0.9403 - val_loss: 0.3136 - val_accuracy: 0.8851
# Epoch 10/30
# 4/4 [==============================] - 0s 92ms/step - loss: 0.2110 - accuracy: 0.9453 - val_loss: 0.2881 - val_accuracy: 0.8966
# Epoch 11/30
# 4/4 [==============================] - 0s 126ms/step - loss: 0.1908 - accuracy: 0.9652 - val_loss: 0.2662 - val_accuracy: 0.8966
# Epoch 12/30
# 4/4 [==============================] - 1s 209ms/step - loss: 0.1719 - accuracy: 0.9751 - val_loss: 0.2510 - val_accuracy: 0.9080
# Epoch 13/30
# 4/4 [==============================] - 1s 188ms/step - loss: 0.1566 - accuracy: 0.9801 - val_loss: 0.2400 - val_accuracy: 0.9080
# Epoch 14/30
# 4/4 [==============================] - 1s 180ms/step - loss: 0.1427 - accuracy: 0.9801 - val_loss: 0.2305 - val_accuracy: 0.9080
# Epoch 15/30
# 4/4 [==============================] - 1s 186ms/step - loss: 0.1314 - accuracy: 0.9851 - val_loss: 0.2228 - val_accuracy: 0.9195
# Epoch 16/30
# 4/4 [==============================] - 1s 186ms/step - loss: 0.1212 - accuracy: 0.9950 - val_loss: 0.2173 - val_accuracy: 0.9195
# Epoch 17/30
# 4/4 [==============================] - 0s 93ms/step - loss: 0.1120 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9310
# Epoch 18/30
# 4/4 [==============================] - 1s 209ms/step - loss: 0.1041 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9310
# Epoch 19/30
# 4/4 [==============================] - 0s 98ms/step - loss: 0.0975 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9310
# Epoch 20/30
# 4/4 [==============================] - 1s 229ms/step - loss: 0.0911 - accuracy: 1.0000 - val_loss: 0.1910 - val_accuracy: 0.9310
# Epoch 21/30
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0855 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 0.9425
# Epoch 22/30
# 4/4 [==============================] - 1s 200ms/step - loss: 0.0800 - accuracy: 1.0000 - val_loss: 0.1787 - val_accuracy: 0.9425
# Epoch 23/30
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0754 - accuracy: 1.0000 - val_loss: 0.1735 - val_accuracy: 0.9425
# Epoch 24/30
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0711 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9425
# Epoch 25/30
# 4/4 [==============================] - 1s 169ms/step - loss: 0.0672 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9425
# Epoch 26/30
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0637 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9425
# Epoch 27/30
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9425
# Epoch 28/30
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0579 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9425
# Epoch 29/30
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0550 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9425
# Epoch 30/30
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9425
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1467 - accuracy: 0.9425
# Test accuracy: 0.943

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim([0, 1.1])
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim([0, 1.1])
plt.legend()

plt.show()
